# %%
# import the packages we are going to be using

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

import pandas as pd
#pd.set_option('display.max_columns', 100)
#import scipy.stats as stats

path = "antropometria-dataset.csv"

# Importar los datos
df = pd.read_csv(path)

df.head(10)
# Out:
#     folio  intp  entidad             desc_ent  sexo  edad  meses    peso  \
# 0  210295     2       21               PUEBLA     2    38      8  73.700
# 1  101655     3       10              DURANGO     2    11     11  35.650
# 2   10287     6        1       AGUASCALIENTES     2    18      8  54.800
# 3   91526     4        9     DISTRITO FEDERAL     1    10      8  33.400
# 4  210939     3       21               PUEBLA     2    19      3  97.950
# 5  241555     3       24      SAN LUIS POTOSI     1    10      7  31.900
# 6  211879     2       21               PUEBLA     2    10      9  31.950
# 7   80135     3        8            CHIHUAHUA     2    11      9  32.400
# 8  240207     4       24      SAN LUIS POTOSI     2    12      2  71.700
# 9   31220     3        3  BAJA CALIFORNIA SUR     1    10     10  48.025
#
#    ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  \
# 0     2  146.40  ...    16:30      2     16:35            1     R2101
# ...

# %%
# Guardar los datos de las variables de interés
df.fillna(method ='ffill', inplace = True) 
#revisar sustitución 
df.head(10)
# Out:
#     folio  intp  entidad             desc_ent  sexo  edad  meses    peso  \
# 0  210295     2       21               PUEBLA     2    38      8  73.700
# 1  101655     3       10              DURANGO     2    11     11  35.650
# 2   10287     6        1       AGUASCALIENTES     2    18      8  54.800
# 3   91526     4        9     DISTRITO FEDERAL     1    10      8  33.400
# 4  210939     3       21               PUEBLA     2    19      3  97.950
# 5  241555     3       24      SAN LUIS POTOSI     1    10      7  31.900
# 6  211879     2       21               PUEBLA     2    10      9  31.950
# 7   80135     3        8            CHIHUAHUA     2    11      9  32.400
# 8  240207     4       24      SAN LUIS POTOSI     2    12      2  71.700
# 9   31220     3        3  BAJA CALIFORNIA SUR     1    10     10  48.025
#
#    ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  \
# 0     2  146.40  ...    16:30      2     16:35            1     R2101
# ...

# %%
#guardar los datos de las variables de interés
sistol = df['sistol']
diastol = df['diastol']

# %%
#Se usa matplotlib.pyplot as plt
#Fijar el tamaño de las gráficas en pulgadas 
plt.figure(figsize=(10,5))

# Visualizamos un histograma al lado del otro
#número de renglones, número de columnas, índice
plt.subplot(1,2,1)
plt.hist(x = sistol, bins = 10)
plt.title("Sistol")

plt.subplot(1,2,2)
plt.hist(x = diastol, bins = 10)
plt.title("Diastol")

#busca los objetos gráficos activos y los muestra 
plt.show()

# %%
#guardar los datos de las variables de interés
peso = df['peso']
cintura = df['cintura']

# %%
#Se usa matplotlib.pyplot as plt
#Fijar el tamaño de las gráficas en pulgadas 
plt.figure(figsize=(10,5))

# Visualizamos un histograma al lado del otro
#número de renglones, número de columnas, índice
plt.subplot(1,2,1)
plt.hist(x = peso, bins = 10)
plt.title("Peso")

plt.subplot(1,2,2)
plt.hist(x = cintura, bins = 10)
plt.title("Cintura")

#busca los objetos gráficos activos y los muestra 
plt.show()

# %%
# Generar un diagrama de dispersión de peso vs. largo
plt.figure(figsize=(5,5))
plt.scatter(x = peso, y = cintura)
plt.xlabel("'peso'")
plt.ylabel("'cintura'")
plt.title("Diagrama de dispersión de peso vs cintura")

plt.show()

# %%
#guardar los datos de las variables de interés
peso_hombres = hombres['peso']
peso_mujeres = mujeres['peso']
cintura_hombres = hombres['cintura']
cintura_mujeres = mujeres['cintura']

# %%
#Se usa matplotlib.pyplot as plt
#Fijar el tamaño de las gráficas en pulgadas 
plt.figure(figsize=(10,5))

# Visualizamos un histograma al lado del otro
#número de renglones, número de columnas, índice
plt.subplot(1,2,1)
plt.hist(x = peso_hombres, bins = 10)
plt.title("Peso de hombres")

plt.subplot(1,2,2)
plt.hist(x = peso_mujeres, bins = 10)
plt.title("Peso de mujeres")

#busca los objetos gráficos activos y los muestra 
plt.show()

# %%
#Se usa matplotlib.pyplot as plt
#Fijar el tamaño de las gráficas en pulgadas 
plt.figure(figsize=(10,5))

# Visualizamos un histograma al lado del otro
#número de renglones, número de columnas, índice
plt.subplot(1,2,1)
plt.hist(x = cintura_hombres, bins = 10)
plt.title("Cintura de hombres")

plt.subplot(1,2,2)
plt.hist(x = cintura_mujeres, bins = 10)
plt.title("Cintura de mujeres")

#busca los objetos gráficos activos y los muestra 
plt.show()

# %%
# Generar un diagrama de dispersión de peso vs. largo
plt.figure(figsize=(5,5))
plt.scatter(x = peso_hombres, y = cintura_hombres)
plt.xlabel("'peso de hombre'")
plt.ylabel("'cintura de hombre'")
plt.title("Diagrama de dispersión de peso vs cintura")

plt.show()

# %%
# Generar un diagrama de dispersión de peso vs. largo
plt.figure(figsize=(5,5))
plt.scatter(x = peso_mujeres, y = cintura_mujeres)
plt.xlabel("'peso de mujer'")
plt.ylabel("'cintura de mujer'")
plt.title("Diagrama de dispersión de peso vs cintura")

plt.show()
